# %%
try:
    import tensorflow as tf
    from tensorflow.python import keras
    import numpy as np
    import pandas as pd
    import matplotlib.pyplot as plt
    # %matplotlib inline
    from sklearn.ensemble import VotingClassifier
    from sklearn.ensemble import RandomForestClassifier
    from sklearn.svm import SVC
    from sklearn.model_selection import train_test_split
    from sklearn.metrics import accuracy_score
    from sklearn.metrics import confusion_matrix,classification_report
    from keras.models import Sequential
    from keras.layers import Dense
    from sklearn.preprocessing import LabelEncoder
    print('Library Loaded .........')
except:
    print('One or More Library was not Found ! ')
# Out:
# Library Loaded .........

# %%
df = pd.read_csv("career_pred.csv")

# %%
df.head()
# Out:
#    Acedamic percentage in Operating Systems  percentage in Algorithms  \
# 0                                        69                        63
# 1                                        78                        62
# 2                                        71                        86
# 3                                        76                        87
# 4                                        92                        62
#
#    Percentage in Programming Concepts  Percentage in Software Engineering  \
# 0                                  78                                  87
# 1                                  73                                  60
# 2                                  91                                  87
# 3                                  60                                  84
# 4                                  90                                  67
#
#    Percentage in Computer Networks  Percentage in Electronics Subjects  \
# ...

# %%
df.shape
# Out:
# (20000, 39)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 39 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Acedamic percentage in Operating Systems  20000 non-null  int64
#  1   percentage in Algorithms                  20000 non-null  int64
#  2   Percentage in Programming Concepts        20000 non-null  int64
#  3   Percentage in Software Engineering        20000 non-null  int64
#  4   Percentage in Computer Networks           20000 non-null  int64
#  5   Percentage in Electronics Subjects        20000 non-null  int64
#  6   Percentage in Computer Architecture       20000 non-null  int64
#  7   Percentage in Mathematics                 20000 non-null  int64
#  8   Percentage in Communication skills        20000 non-null  int64
#  9   Hours working per day                     20000 non-null  int64
# ...

# %% [markdown]
# ## Checking for Null Values
#
# To ensure data quality, it is important to check for any null values in the dataset. The following code calculates the number of null values in each column of the dataframe `df`:
#
# ```python
#     null_values = df.isnull().sum()
#     print(null_values)
# ```
#
# This will help us identify if there are any missing values that need to be addressed before proceeding with further analysis.

# %%
null_values = df.isnull().sum()
print(null_values)
# Out:
# Acedamic percentage in Operating Systems    0
# percentage in Algorithms                    0
# Percentage in Programming Concepts          0
# Percentage in Software Engineering          0
# Percentage in Computer Networks             0
# Percentage in Electronics Subjects          0
# Percentage in Computer Architecture         0
# Percentage in Mathematics                   0
# Percentage in Communication skills          0
# Hours working per day                       0
# Logical quotient rating                     0
# hackathons                                  0
# coding skills rating                        0
# public speaking points                      0
# can work long time before system?           0
# self-learning capability?                   0
# Extra-courses did                           0
# certifications                              0
# workshops                                   0
# talenttests taken?                          0
# ...

# %%
df.describe().T
# Out:
#                                             count      mean        std   min  \
# Acedamic percentage in Operating Systems  20000.0  77.00230  10.085697  60.0
# percentage in Algorithms                  20000.0  76.94820  10.101733  60.0
# Percentage in Programming Concepts        20000.0  77.01755  10.134815  60.0
# Percentage in Software Engineering        20000.0  77.09450  10.087837  60.0
# Percentage in Computer Networks           20000.0  76.95820  10.020088  60.0
# Percentage in Electronics Subjects        20000.0  77.01555  10.168888  60.0
# Percentage in Computer Architecture       20000.0  77.06985  10.069059  60.0
# Percentage in Mathematics                 20000.0  76.91310  10.138555  60.0
# Percentage in Communication skills        20000.0  76.92145  10.103494  60.0
# Hours working per day                     20000.0   7.98595   2.593798   4.0
# Logical quotient rating                   20000.0   4.99505   2.578383   1.0
# ...

# %%
df_copy = df.copy()

# %%
df_copy.head()
# Out:
#    Acedamic percentage in Operating Systems  percentage in Algorithms  \
# 0                                        69                        63
# 1                                        78                        62
# 2                                        71                        86
# 3                                        76                        87
# 4                                        92                        62
#
#    Percentage in Programming Concepts  Percentage in Software Engineering  \
# 0                                  78                                  87
# 1                                  73                                  60
# 2                                  91                                  87
# 3                                  60                                  84
# 4                                  90                                  67
#
#    Percentage in Computer Networks  Percentage in Electronics Subjects  \
# ...

# %%
def change_string_to_int(column):
    variables=pd.unique(df_copy[column])
    for item in range(variables.size):
        df_copy[column]=[item if each==variables[item] else each for each in df_copy[column]]
    return df_copy[column]

# %%
object_columns = df.select_dtypes(include=['object'])

for column in object_columns.columns:
    unique_elements = object_columns[column].unique()
    print(f"Unique elements in '{column}':")
    print(unique_elements)
    print("\n")
# Out:
# Unique elements in 'can work long time before system?':
# ['yes' 'no']
#
#
# Unique elements in 'self-learning capability?':
# ['yes' 'no']
#
#
# Unique elements in 'Extra-courses did':
# ['yes' 'no']
#
#
# Unique elements in 'certifications':
# ['shell programming' 'machine learning' 'app development' 'python'
#  'r programming' 'information security' 'hadoop' 'distro making'
#  'full stack']
#
#
# Unique elements in 'workshops':
# ['cloud computing' 'database security' 'web technologies' 'data science'
#  'testing' 'hacking' 'game development' 'system designing']
#
#
# Unique elements in 'talenttests taken?':
# ['no' 'yes']
#
#
# Unique elements in 'olympiads':
# ['yes' 'no']
#
#
# Unique elements in 'reading and writing skills':
# ['excellent' 'poor' 'medium']
#
#
# Unique elements in 'memory capability score':
# ['excellent' 'medium' 'poor']
#
#
# Unique elements in 'Interested subjects':
# ['cloud computing' 'networks' 'hacking' 'Computer Architecture'
# ...

# %%
for column in object_columns.columns:
    label_encoder = LabelEncoder()

    numeric = label_encoder.fit_transform(df_copy[column].unique())
    df_copy[column] = label_encoder.transform(df_copy[column])
    # Create a new DataFrame with the original and encoded values
    encoded_df = pd.DataFrame({column: df[column].unique(), column+' Associated Number': numeric})
    print(encoded_df)
# Out:
#   can work long time before system?  \
# 0                               yes
# 1                                no
#
#    can work long time before system? Associated Number
# 0                                                  1
# 1                                                  0
#   self-learning capability?  self-learning capability? Associated Number
# 0                       yes                                            1
# 1                        no                                            0
#   Extra-courses did  Extra-courses did Associated Number
# 0               yes                                    1
# 1                no                                    0
#          certifications  certifications Associated Number
# 0     shell programming                                 8
# 1      machine learning                                 5
# 2       app development                                 0
# 3                python                                 6
# ...

# %%
df_copy.head()
# Out:
#    Acedamic percentage in Operating Systems  percentage in Algorithms  \
# 0                                        69                        63
# 1                                        78                        62
# 2                                        71                        86
# 3                                        76                        87
# 4                                        92                        62
#
#    Percentage in Programming Concepts  Percentage in Software Engineering  \
# 0                                  78                                  87
# 1                                  73                                  60
# 2                                  91                                  87
# 3                                  60                                  84
# 4                                  90                                  67
#
#    Percentage in Computer Networks  Percentage in Electronics Subjects  \
# ...

# %%
# object_columns = df.select_dtypes(include=['object'])

# for column in object_columns.columns:
#     print(f"Description of '{column}':")
#     print(object_columns[column].describe())
#     print("\n")

# %%
# # List of columns to be label encoded
# columns_to_encode = [
#     'can work long time before system?', 'self-learning capability?', 'Extra-courses did',
#     'talenttests taken?', 'olympiads', 'In a Realtionship?', 'Gentle or Tuff behaviour?',
#     'Management or Technical', 'Salary/work', 'hard/smart worker', 'worked in teams ever?', 'Introvert',
#     'Taken inputs from seniors or elders','interested in games','Job/Higher Studies?','Salary Range Expected'
# ]

# # Initialize the LabelEncoder
# label_encoder = LabelEncoder()

# # Apply label encoding to the specified columns
# for column in columns_to_encode:
#     df_copy[column] = label_encoder.fit_transform(df_copy[column])
#     # print(df_copy[column])
# # Display the first few rows to verify the changes
# df_copy.head()

# %% [markdown]
# ## Splitting the Dataset into Features and Target Variable
#
# To prepare the dataset for modeling, we need to split it into features (`X`) and the target variable (`y`). The target variable in this dataset is `Suggested Job Role`, and the remaining columns will be used as features.
#
# The following code performs this split:
#
# ```python
# y = df['Suggested Job Role']
# X = df.drop(columns=['Suggested Job Role'])
# ```
#
# This will create two new variables, `X` and `y`, which can be used for training machine learning models.

# %%
# # Define the target variable
# y = df['Suggested Job Role']

# # Define the feature variables
# X = df.drop(columns=['Suggested Job Role'])

# # Display the shapes of X and y to verify
# print(f"Shape of X: {X.shape}")
# print(f"Shape of y: {y.shape}")

# %%
# df_copy.info()
